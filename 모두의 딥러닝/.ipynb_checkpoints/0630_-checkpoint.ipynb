# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, \
Flatten, Reshape

import matplotlib.pyplot as plt 
import numpy as np 

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# %%
#생성자 모델을 만듭니다.
autoencoder = Sequential()

#인코딩 부분입니다 ,
autoencoder.add(Conv2D(16, kernel_size = 3, padding = 'same', input_shape=(28, 28, 1), \
                      activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding = 'same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding= 'same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides= 2,  padding='same', activation='relu' ))

# %%
#디코딩 부분입니다. 
autoencoder.add(Conv2D(8, kernel_size= 3, padding='same', activation= 'relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# %%
# 전체 구조를 확인해 봅니다. 
autoencoder.summary()

# 컴파일 및 학습을 하는 부분입니다. 
autoencoder.compile(optimizer='adam', loss= 'binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, 
               validation_data = (X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)
ae_imgs = autoencoder.predict(X_test) # 앞서 만든 오토인코더 모델에 집어 넣습니다.
plt.figure(figsize= (7, 2)) #출력될 이미지의 크기를 정함

for i, image_idx in enumerate(random_test):  #랜덤하게 뽑은 이미지를 차례로 나열 
    ax = plt.subplot(2, 7, i + 1)
    plt.imshow(X_test[image_idx].reshape(28, 28)) # 테스트할 이미지를 먼저 그대로 보여줍니다.
    ax.axis('off')
    ax = plt.subplot(2, 7, 7 + i + 1)
    plt.imshow(ae_imgs[image_idx].reshape(28, 28)) # 오토인코딩 결과를 다음열에 출력 
    ax.axis('off')
    
plt.show
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 35s 75ms/step - loss: 0.2247 - val_loss: 0.1388
# Epoch 2/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.1289 - val_loss: 0.1194
# Epoch 3/50
# 469/469 [==============================] - 35s 76ms/step - loss: 0.1157 - val_loss: 0.1108
# Epoch 4/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.1093 - val_loss: 0.1060
# Epoch 5/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.1051 - val_loss: 0.1023
# Epoch 6/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.1021 - val_loss: 0.0996
# Epoch 7/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0997 - val_loss: 0.0975
# Epoch 8/50
# 469/469 [==============================] - 28s 59ms/step - loss: 0.0979 - val_loss: 0.0960
# Epoch 9/50
# 469/469 [==============================] - 28s 59ms/step - loss: 0.0963 - val_loss: 0.0944
# Epoch 10/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0950 - val_loss: 0.0933
# Epoch 11/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0939 - val_loss: 0.0922
# Epoch 12/50
# 469/469 [==============================] - 26s 56ms/step - loss: 0.0930 - val_loss: 0.0915
# Epoch 13/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0922 - val_loss: 0.0907
# Epoch 14/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0916 - val_loss: 0.0900
# Epoch 15/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0910 - val_loss: 0.0896
# Epoch 16/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0905 - val_loss: 0.0890
# Epoch 17/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0900 - val_loss: 0.0890
# Epoch 18/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0896 - val_loss: 0.0883
# Epoch 19/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0892 - val_loss: 0.0880
# Epoch 20/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0888 - val_loss: 0.0877
# Epoch 21/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0885 - val_loss: 0.0874
# Epoch 22/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0882 - val_loss: 0.0868
# Epoch 23/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0879 - val_loss: 0.0869
# Epoch 24/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0876 - val_loss: 0.0863
# Epoch 25/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0874 - val_loss: 0.0861
# Epoch 26/50
# 469/469 [==============================] - 25s 52ms/step - loss: 0.0871 - val_loss: 0.0859
# Epoch 27/50
# 469/469 [==============================] - 24s 52ms/step - loss: 0.0869 - val_loss: 0.0860
# Epoch 28/50
# 469/469 [==============================] - 25s 52ms/step - loss: 0.0867 - val_loss: 0.0857
# Epoch 29/50
# 469/469 [==============================] - 25s 52ms/step - loss: 0.0865 - val_loss: 0.0853
# Epoch 30/50
# 469/469 [==============================] - 25s 52ms/step - loss: 0.0864 - val_loss: 0.0858
# Epoch 31/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0862 - val_loss: 0.0850
# Epoch 32/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0860 - val_loss: 0.0849
# Epoch 33/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0859 - val_loss: 0.0848
# Epoch 34/50
# 469/469 [==============================] - 25s 52ms/step - loss: 0.0857 - val_loss: 0.0846
# Epoch 35/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0856 - val_loss: 0.0845
# Epoch 36/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0855 - val_loss: 0.0843
# Epoch 37/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0854 - val_loss: 0.0848
# Epoch 38/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0853 - val_loss: 0.0843
# Epoch 39/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0852 - val_loss: 0.0846
# Epoch 40/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0851 - val_loss: 0.0844
# Epoch 41/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0850 - val_loss: 0.0838
# Epoch 42/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0849 - val_loss: 0.0842
# Epoch 43/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0848 - val_loss: 0.0838
# Epoch 44/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0847 - val_loss: 0.0836
# Epoch 45/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0846 - val_loss: 0.0836
# Epoch 46/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0846 - val_loss: 0.0835
# Epoch 47/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0845 - val_loss: 0.0833
# Epoch 48/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0844 - val_loss: 0.0833
# Epoch 49/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0843 - val_loss: 0.0832
# Epoch 50/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0843 - val_loss: 0.0831
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 암 구별

# %%
import tensorflow as tf 
import matplotlib.pyplot as plt 
import numpy as np 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, \
Flatten, Reshape, Dropout, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, initializers, regularizers, metrics

np.random.seed(3)
tf.random.set_seed(3)

train_datagen = ImageDataGenerator(rescale= 1./255,
                                  horizontal_flip= True,  # 수평 대칭 이미지를 50%
                                  width_shift_range= 0.1,  # 전체크기의 10% 범위에서 좌우로 
                                  height_shift_range= 0.1, # 마찬가지로 위, 아래 이동 
                                  fill_mode = 'nearest')

train_generator = train_datagen.flow_from_directory(\
        './train', # 학습셋이 있는 폴더의 위치 
        target_size = (150, 150),
        batch_size = 5,
        class_mode = 'binary')

# 테스트 셋은 이미지 부풀리기 과정을 진행하지 않습니다. 
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(\
        './test',
        target_size=(150, 150),
        batch_size= 5, 
        class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %%
# 앞서 배운 CNN 모델을 만들어 적용해 보겠습니다. 

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape= (150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size =(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
# 모델을 컴파일 합니다. 
model.compile(loss= 'sparse_categorical_crossentropy', \
             optimizer = optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

history = model.fit_generator(
       train_generator,
       steps_per_epoch=30,
       epochs=50,
       validation_data=test_generator,
       validation_steps=10)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 2s 74ms/step - loss: 0.7008 - accuracy: 0.5400 - val_loss: 0.6903 - val_accuracy: 0.4800
# Epoch 2/50
# 30/30 [==============================] - 2s 75ms/step - loss: 0.6845 - accuracy: 0.5600 - val_loss: 0.6597 - val_accuracy: 0.6400
# Epoch 3/50
# 30/30 [==============================] - 2s 73ms/step - loss: 0.6865 - accuracy: 0.5200 - val_loss: 0.6620 - val_accuracy: 0.5800
# Epoch 4/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.6868 - accuracy: 0.5733 - val_loss: 0.6618 - val_accuracy: 0.5800
# Epoch 5/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.6769 - accuracy: 0.5600 - val_loss: 0.6457 - val_accuracy: 0.6000
# Epoch 6/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.6443 - accuracy: 0.6800 - val_loss: 0.6182 - val_accuracy: 0.7600
# Epoch 7/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.6313 - accuracy: 0.6533 - val_loss: 0.6313 - val_accuracy: 0.5600
# Epoch 8/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.5804 - accuracy: 0.7267 - val_loss: 0.5536 - val_accuracy: 0.6800
# Epoch 9/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.5579 - accuracy: 0.7333 - val_loss: 0.6800 - val_accuracy: 0.5200
# Epoch 10/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.5728 - accuracy: 0.7133 - val_loss: 0.5349 - val_accuracy: 0.7400
# Epoch 11/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4711 - accuracy: 0.8133 - val_loss: 0.4056 - val_accuracy: 0.8200
# Epoch 12/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.4183 - accuracy: 0.8333 - val_loss: 0.3277 - val_accuracy: 0.8800
# Epoch 13/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.3112 - accuracy: 0.9000 - val_loss: 0.2273 - val_accuracy: 0.9400
# Epoch 14/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.3707 - accuracy: 0.8400 - val_loss: 0.2884 - val_accuracy: 0.8600
# Epoch 15/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.3333 - accuracy: 0.9000 - val_loss: 0.2298 - val_accuracy: 0.9000
# Epoch 16/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.2410 - accuracy: 0.9067 - val_loss: 0.4719 - val_accuracy: 0.7400
# Epoch 17/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.2711 - accuracy: 0.8933 - val_loss: 0.1690 - val_accuracy: 0.9200
# Epoch 18/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.2550 - accuracy: 0.9000 - val_loss: 0.2082 - val_accuracy: 0.8800
# Epoch 19/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.2095 - accuracy: 0.9200 - val_loss: 0.1426 - val_accuracy: 0.9600
# Epoch 20/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.1734 - accuracy: 0.9333 - val_loss: 0.1280 - val_accuracy: 0.9600
# Epoch 21/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1660 - accuracy: 0.9533 - val_loss: 0.1460 - val_accuracy: 0.9600
# Epoch 22/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.2147 - accuracy: 0.9333 - val_loss: 0.1498 - val_accuracy: 0.9600
# Epoch 23/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.1939 - accuracy: 0.9200 - val_loss: 0.1106 - val_accuracy: 0.9600
# Epoch 24/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1220 - accuracy: 0.9667 - val_loss: 0.1111 - val_accuracy: 0.9600
# Epoch 25/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.1258 - accuracy: 0.9667 - val_loss: 0.1406 - val_accuracy: 0.9400
# Epoch 26/50
# 30/30 [==============================] - 2s 73ms/step - loss: 0.1795 - accuracy: 0.9533 - val_loss: 0.0820 - val_accuracy: 0.9800
# Epoch 27/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.1311 - accuracy: 0.9533 - val_loss: 0.1042 - val_accuracy: 0.9600
# Epoch 28/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0898 - accuracy: 0.9600 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 29/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1632 - accuracy: 0.9133 - val_loss: 0.0745 - val_accuracy: 0.9800
# Epoch 30/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1380 - accuracy: 0.9467 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 31/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1345 - accuracy: 0.9600 - val_loss: 0.0774 - val_accuracy: 0.9600
# Epoch 32/50
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1296 - accuracy: 0.9600 - val_loss: 0.0608 - val_accuracy: 0.9800
# Epoch 33/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0886 - accuracy: 0.9667 - val_loss: 0.2107 - val_accuracy: 0.9200
# Epoch 34/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1196 - accuracy: 0.9600 - val_loss: 0.2234 - val_accuracy: 0.9200
# Epoch 35/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.1346 - accuracy: 0.9600 - val_loss: 0.0603 - val_accuracy: 0.9800
# Epoch 36/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0770 - accuracy: 0.9867 - val_loss: 0.0895 - val_accuracy: 0.9800
# Epoch 37/50
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1158 - accuracy: 0.9733 - val_loss: 0.2258 - val_accuracy: 0.9200
# Epoch 38/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0602 - accuracy: 0.9867 - val_loss: 0.0986 - val_accuracy: 0.9400
# Epoch 39/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0704 - accuracy: 0.9800 - val_loss: 0.1257 - val_accuracy: 0.9600
# Epoch 40/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1023 - accuracy: 0.9733 - val_loss: 0.0675 - val_accuracy: 0.9600
# Epoch 41/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0567 - accuracy: 0.9800 - val_loss: 0.1147 - val_accuracy: 0.9600
# Epoch 42/50
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0580 - accuracy: 0.9800 - val_loss: 0.0496 - val_accuracy: 0.9800
# Epoch 43/50
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0749 - accuracy: 0.9667 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 44/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0613 - accuracy: 0.9800 - val_loss: 0.0643 - val_accuracy: 0.9800
# Epoch 45/50
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0587 - accuracy: 0.9933 - val_loss: 0.1142 - val_accuracy: 0.9800
# Epoch 46/50
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1186 - accuracy: 0.9467 - val_loss: 0.0358 - val_accuracy: 0.9800
# Epoch 47/50
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0823 - accuracy: 0.9733 - val_loss: 0.0786 - val_accuracy: 0.9600
# Epoch 48/50
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0904 - accuracy: 0.9733 - val_loss: 0.0796 - val_accuracy: 0.9600
# Epoch 49/50
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0550 - accuracy: 0.9800 - val_loss: 0.0446 - val_accuracy: 0.9800
# Epoch 50/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0912 - accuracy: 0.9733 - val_loss: 0.0722 - val_accuracy: 0.9800

# %%
# 결과를 그래프로 표현하는 부분
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c='red', label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c='lightcoral', label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c='cornflowerblue', label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='Trainset_loss')

plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
